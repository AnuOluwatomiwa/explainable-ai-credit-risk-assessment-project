# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Standardizing and Encoding Dataset

# %%
df_cleaned = pd.read_excel('../data/dataset_v1.xlsx', index_col = 'Loan_ID')
df_cleaned.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0  146.369492               360
# LP001003             4583             1508.0  128.000000               360
# LP001005             3000                0.0   66.000000               360
# LP001006             2583             2358.0  120.000000               360
# LP001008             6000                0.0  141.000000               360
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002               1         Urban           Y
# LP001003               1         Rural           N
# LP001005               1         Urban           Y
# LP001006               1         Urban           Y
# LP001008               1         Urban           Y

# %% [markdown]
# #### Converting the Credit_History column from int64 to float64

# %%
print(df_cleaned['Credit_History'].dtype)  # To see the data type
# Out:
# int64

# %%
df_cleaned['Credit_History'] = df_cleaned['Credit_History'].astype(float)

# %%
print(df_cleaned['Credit_History'].dtype)
# Out:
# float64

# %%
x = df_cleaned.drop('Loan_Status', axis = 1)
y = df_cleaned['Loan_Status'].copy()

# %%
num_values = x.select_dtypes(include = np.number)
cat_values = x.select_dtypes(exclude = np.number)

# %%
cat_values.shape, num_values.shape, x.shape
# Out:
# ((611, 6), (611, 5), (611, 11))

# %% [markdown]
# ## Handling The Categorical Columns

# %%
cat_values.head()
# Out:
#          Gender Married Dependents     Education Self_Employed Property_Area
# Loan_ID
# LP001002   Male      No          0      Graduate            No         Urban
# LP001003   Male     Yes          1      Graduate            No         Rural
# LP001005   Male     Yes          0      Graduate           Yes         Urban
# LP001006   Male     Yes          0  Not Graduate            No         Urban
# LP001008   Male      No          0      Graduate            No         Urban

# %%
def convert_to_0_1(row):
    return 1 if (row == 'Male') or (row == 'Yes') else 0

# %%
cat_values["Married"] = cat_values["Married"].apply(convert_to_0_1)
cat_values["Self_Employed"] = cat_values["Self_Employed"].apply(convert_to_0_1)
cat_values["Gender"] = cat_values["Gender"].apply(convert_to_0_1)

# %%
cat_values.head()
# Out:
#           Gender  Married Dependents     Education  Self_Employed  \
# Loan_ID
# LP001002       1        0          0      Graduate              0
# LP001003       1        1          1      Graduate              0
# LP001005       1        1          0      Graduate              1
# LP001006       1        1          0  Not Graduate              0
# LP001008       1        0          0      Graduate              0
#
#          Property_Area
# Loan_ID
# LP001002         Urban
# LP001003         Rural
# LP001005         Urban
# LP001006         Urban
# LP001008         Urban

# %%
cat_values_ordinal = cat_values.loc[:, ["Gender", "Married", "Self_Employed"]]
cat_values_to_one_hot = cat_values.drop(["Gender", "Married", "Self_Employed"], axis = 1)

# %%
cat_values_to_one_hot = pd.get_dummies(cat_values_to_one_hot)

# %%
cat_values_to_one_hot.head()
# Out:
#           Dependents_0  Dependents_1  Dependents_2  Dependents_3+  \
# Loan_ID
# LP001002          True         False         False          False
# LP001003         False          True         False          False
# LP001005          True         False         False          False
# LP001006          True         False         False          False
# LP001008          True         False         False          False
#
#           Education_Graduate  Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                True                   False                False
# LP001003                True                   False                 True
# LP001005                True                   False                False
# LP001006               False                    True                False
# LP001008                True                   False                False
#
#           Property_Area_Semiurban  Property_Area_Urban
# Loan_ID
# LP001002                    False                 True
# LP001003                    False                False
# LP001005                    False                 True
# LP001006                    False                 True
# LP001008                    False                 True

# %%
cat_values_ordinal.head()
# Out:
#           Gender  Married  Self_Employed
# Loan_ID
# LP001002       1        0              0
# LP001003       1        1              0
# LP001005       1        1              1
# LP001006       1        1              0
# LP001008       1        0              0

# %%
perfect_cat_values = pd.concat([cat_values_ordinal, cat_values_to_one_hot], axis = 1)

# %%
perfect_cat_values.head()
# Out:
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001002       1        0              0          True         False
# LP001003       1        1              0         False          True
# LP001005       1        1              1          True         False
# LP001006       1        1              0          True         False
# LP001008       1        0              0          True         False
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001002         False          False                True
# LP001003         False          False                True
# LP001005         False          False                True
# LP001006         False          False               False
# LP001008         False          False                True
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                   False                False
# LP001003                   False                 True
# LP001005                   False                False
# LP001006                    True                False
# LP001008                   False                False
#
#           Property_Area_Semiurban  Property_Area_Urban
# Loan_ID
# LP001002                    False                 True
# LP001003                    False                False
# LP001005                    False                 True
# LP001006                    False                 True
# LP001008                    False                 True

# %% [markdown]
# # Handling The Numerical Columns

# %%
num_values.head()
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0  146.369492               360
# LP001003             4583             1508.0  128.000000               360
# LP001005             3000                0.0   66.000000               360
# LP001006             2583             2358.0  120.000000               360
# LP001008             6000                0.0  141.000000               360
#
#           Credit_History
# Loan_ID
# LP001002             1.0
# LP001003             1.0
# LP001005             1.0
# LP001006             1.0
# LP001008             1.0

# %%
num_values.Credit_History.value_counts()
# Out:
# Credit_History
# 1.0    494
# 0.0    117
# Name: count, dtype: int64

# %%
df_cleaned.shape
# Out:
# (611, 12)

# %%
perfect_cat_values = pd.concat([perfect_cat_values, num_values["Credit_History"]], axis = 1)
num_values = num_values.drop("Credit_History", axis = 1)

# %%
perfect_cat_values.head(2)
# Out:
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001002       1        0              0          True         False
# LP001003       1        1              0         False          True
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001002         False          False                True
# LP001003         False          False                True
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                   False                False
# LP001003                   False                 True
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History
# Loan_ID
# LP001002                    False                 True             1.0
# LP001003                    False                False             1.0

# %%
num_values.head(2)
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# Loan_ID
# LP001002             5849                0.0  146.369492               360
# LP001003             4583             1508.0  128.000000               360

# %%
num_values_cols = num_values.columns
list(num_values_cols)
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
std = StandardScaler()
num_values_arrays = std.fit_transform(num_values)

# %% [markdown]
# ### `std.fit` calculates the standard deviation and mean of each columns in the dataset
# ### `std.transform` applies the mean and standard deviation to each row in this fomula -> `(x-mean)/standard deviation`

# %%
num_values_arrays
# Out:
# array([[ 7.34964378e-02, -5.55745555e-01, -3.37663141e-16,
#          2.75515640e-01],
#        [-1.33509947e-01, -4.09552064e-02, -2.18238112e-01,
#          2.75515640e-01],
#        [-3.92349684e-01, -5.55745555e-01, -9.54826979e-01,
#          2.75515640e-01],
#        ...,
#        [ 4.36983952e-01, -4.73816056e-01,  1.26682009e+00,
#          2.75515640e-01],
#        [ 3.57026510e-01, -5.55745555e-01,  4.82709358e-01,
#          2.75515640e-01],
#        [-1.33509947e-01, -5.55745555e-01, -1.58835784e-01,
#          2.75515640e-01]])

# %%
standardized_num_values = pd.DataFrame(num_values_arrays, columns = list(num_values_cols), index = num_values.index)
standardized_num_values.head()
# Out:
#           ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term
# Loan_ID
# LP001002         0.073496          -0.555746 -3.376631e-16          0.275516
# LP001003        -0.133510          -0.040955 -2.182381e-01          0.275516
# LP001005        -0.392350          -0.555746 -9.548270e-01          0.275516
# LP001006        -0.460534           0.249212 -3.132818e-01          0.275516
# LP001008         0.098187          -0.555746 -6.379206e-02          0.275516

# %%
restructured_x = pd.concat([standardized_num_values, perfect_cat_values], axis = 1)
restructured_x.head()
# Out:
#           ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.073496          -0.555746 -3.376631e-16          0.275516
# LP001003        -0.133510          -0.040955 -2.182381e-01          0.275516
# LP001005        -0.392350          -0.555746 -9.548270e-01          0.275516
# LP001006        -0.460534           0.249212 -3.132818e-01          0.275516
# LP001008         0.098187          -0.555746 -6.379206e-02          0.275516
#
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001002       1        0              0          True         False
# LP001003       1        1              0         False          True
# LP001005       1        1              1          True         False
# LP001006       1        1              0          True         False
# LP001008       1        0              0          True         False
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001002         False          False                True
# LP001003         False          False                True
# LP001005         False          False                True
# LP001006         False          False               False
# LP001008         False          False                True
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                   False                False
# LP001003                   False                 True
# LP001005                   False                False
# LP001006                    True                False
# LP001008                   False                False
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History
# Loan_ID
# LP001002                    False                 True             1.0
# LP001003                    False                False             1.0
# LP001005                    False                 True             1.0
# LP001006                    False                 True             1.0
# LP001008                    False                 True             1.0

# %%
full_df = pd.concat([restructured_x, y], axis =1)
full_df.head()
# Out:
#           ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.073496          -0.555746 -3.376631e-16          0.275516
# LP001003        -0.133510          -0.040955 -2.182381e-01          0.275516
# LP001005        -0.392350          -0.555746 -9.548270e-01          0.275516
# LP001006        -0.460534           0.249212 -3.132818e-01          0.275516
# LP001008         0.098187          -0.555746 -6.379206e-02          0.275516
#
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001002       1        0              0          True         False
# LP001003       1        1              0         False          True
# LP001005       1        1              1          True         False
# LP001006       1        1              0          True         False
# LP001008       1        0              0          True         False
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001002         False          False                True
# LP001003         False          False                True
# LP001005         False          False                True
# LP001006         False          False               False
# LP001008         False          False                True
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                   False                False
# LP001003                   False                 True
# LP001005                   False                False
# LP001006                    True                False
# LP001008                   False                False
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History  \
# Loan_ID
# LP001002                    False                 True             1.0
# LP001003                    False                False             1.0
# LP001005                    False                 True             1.0
# LP001006                    False                 True             1.0
# LP001008                    False                 True             1.0
#
#          Loan_Status
# Loan_ID
# LP001002           Y
# LP001003           N
# LP001005           Y
# LP001006           Y
# LP001008           Y

# %%
len(full_df.columns)
# Out:
# 18

# %%
full_df["Loan_Status"] = full_df["Loan_Status"].apply(lambda x: 1 if x == "Y" else 0)

# %%
full_df.sample(10)
# Out:
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001671        -0.324329           0.405561   -0.396445          0.275516
# LP001924        -0.366515           0.486466   -0.681576          0.275516
# LP001404        -0.365043           0.223609    0.090654          0.275516
# LP002813         2.302985          -0.555746    5.389342          0.275516
# LP002841        -0.365207           0.148848   -0.503369          0.275516
# LP002522        -0.474106          -0.555746   -0.634054          0.275516
# LP001146        -0.450396           0.618577   -0.313282          0.275516
# LP002863         0.164573          -0.555746    0.043132          0.275516
# LP002619        -0.259251          -0.049490   -0.265760         -0.659707
# LP001841        -0.460534           0.184010   -0.503369          0.275516
#
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001671       0        1              0          True         False
# LP001924       1        0              0          True         False
# LP001404       0        1              0          True         False
# LP002813       0        1              1         False          True
# LP002841       1        1              0          True         False
# LP002522       0        0              1          True         False
# LP001146       0        1              0          True         False
# LP002863       1        1              0         False         False
# LP002619       1        1              0          True         False
# LP001841       1        0              1          True         False
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001671         False          False                True
# LP001924         False          False                True
# LP001404         False          False                True
# LP002813         False          False                True
# LP002841         False          False                True
# LP002522         False          False                True
# LP001146         False          False                True
# LP002863         False           True                True
# LP002619         False          False               False
# LP001841         False          False               False
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001671                   False                False
# LP001924                   False                 True
# LP001404                   False                False
# LP002813                   False                False
# LP002841                   False                False
# LP002522                   False                False
# LP001146                   False                False
# LP002863                   False                False
# LP002619                    True                False
# LP001841                    True                 True
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History  \
# Loan_ID
# LP001671                     True                False             1.0
# LP001924                    False                False             1.0
# LP001404                     True                False             1.0
# LP002813                     True                False             1.0
# LP002841                    False                 True             0.0
# LP002522                    False                 True             0.0
# LP001146                    False                 True             0.0
# LP002863                     True                False             1.0
# LP002619                     True                False             1.0
# LP001841                    False                False             1.0
#
#           Loan_Status
# Loan_ID
# LP001671            1
# LP001924            1
# LP001404            1
# LP002813            1
# LP002841            0
# LP002522            1
# LP001146            0
# LP002863            0
# LP002619            1
# LP001841            1

# %%
full_df.to_excel("../data/dataset_v2.xlsx" , index = None)
