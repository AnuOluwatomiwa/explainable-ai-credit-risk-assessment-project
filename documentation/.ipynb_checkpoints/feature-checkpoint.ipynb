# %% [markdown]
# ## Importing Necessary Libraries

# %%
import joblib
import pandas as pd
import pickle
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# * Check correlation

# %%
full_df = pd.read_excel("data/dataset_v2.xlsx", index_col = "Loan_ID")
full_df.shape
# Out:
# (611, 18)

# %%
full_df.head()
# Out:
#           ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.073496          -0.555746 -3.376631e-16          0.275516
# LP001003        -0.133510          -0.040955 -2.182381e-01          0.275516
# LP001005        -0.392350          -0.555746 -9.548270e-01          0.275516
# LP001006        -0.460534           0.249212 -3.132818e-01          0.275516
# LP001008         0.098187          -0.555746 -6.379206e-02          0.275516
#
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001002       1        0              0             1             0
# LP001003       1        1              0             0             1
# LP001005       1        1              1             1             0
# LP001006       1        1              0             1             0
# LP001008       1        0              0             1             0
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001002             0              0                   1
# LP001003             0              0                   1
# LP001005             0              0                   1
# LP001006             0              0                   0
# LP001008             0              0                   1
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                       0                    0
# LP001003                       0                    1
# LP001005                       0                    0
# LP001006                       1                    0
# LP001008                       0                    0
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History  \
# Loan_ID
# LP001002                        0                    1               1
# LP001003                        0                    0               1
# LP001005                        0                    1               1
# LP001006                        0                    1               1
# LP001008                        0                    1               1
#
#           Loan_Status
# Loan_ID
# LP001002            1
# LP001003            0
# LP001005            1
# LP001006            1
# LP001008            1

# %%
sns.heatmap(full_df.corr())
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Generation
#
#
# 1. **Total Income**: Combine `ApplicantIncome` and `CoapplicantIncome` to create a new feature representing the total income of the applicant and co-applicant.
#
# 2. **Loan Amount to Total Income Ratio**: Calculate the ratio of `LoanAmount` to the total income to assess the loan amount in relation to the applicant's financial situation.
#
# 3. **Dependents Ratio**: Convert `Dependents` into a numerical feature representing the ratio of dependents to the total number of family members (applicant + co-applicant).
#
# 4. **Income Stability**: Calculate the standard deviation or coefficient of variation of `ApplicantIncome` and `CoapplicantIncome` to represent income stability.

# %% [markdown]
# ## import our cleaned_df

# %%
cleaned_df = pd.read_excel('data/dataset_v1.xlsx', index_col = "Loan_ID")
cleaned_df.head(2)
# Out:
#          Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001002   Male      No          0  Graduate            No             5849
# LP001003   Male     Yes          1  Graduate            No             4583
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001002                0.0  146.369492               360               1
# LP001003             1508.0  128.000000               360               1
#
#          Property_Area Loan_Status
# Loan_ID
# LP001002         Urban           Y
# LP001003         Rural           N

# %% [markdown]
# ### Total Income
#
# `total_income = applicant_income + coapplicant_income`

# %%
total_income = cleaned_df['ApplicantIncome'] + cleaned_df['CoapplicantIncome']

# %% [markdown]
# ### Loan Amount to Total Income Ratio
#
# `loan_amt_to_total_income_ratio = LoanAmt / total_income`

# %%
loan_amt_to_total_income_ratio = cleaned_df['LoanAmount'] / total_income

# %% [markdown]
# ### Dependents Ratio
#
# `dependents_ratio = (dependents / (dependents+1)`

# %%
dependents = cleaned_df['Dependents'].replace('3+', 3).astype(float)

total_family_members = dependents + 1

# Calculate Dependents Ratio
dependents_ratio = dependents / total_family_members
# Out:
# /tmp/ipykernel_132625/3236854274.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dependents = cleaned_df['Dependents'].replace('3+', 3).astype(float)

# %% [markdown]
# ### Income Stability
#
# * `ApplicantIncomeStd = ApplicantIncome.std()`
#
# * `CoapplcantIncomeStd = CoapplicantIncome.std()`

# %%
new_columns = {
    'TotalIncome': total_income,
    'LoanAmtToTotalIncomeRatio': loan_amt_to_total_income_ratio,
    'DependentsRatio': dependents_ratio 
}

new_columns_df = pd.DataFrame(new_columns)
new_columns_df.sample(20)
# Out:
#           TotalIncome  LoanAmtToTotalIncomeRatio  DependentsRatio
# Loan_ID
# LP002547      18333.0                   0.027273         0.500000
# LP001798      10819.0                   0.011092         0.666667
# LP001877       6095.0                   0.024610         0.666667
# LP002422      37719.0                   0.004030         0.500000
# LP002301       7441.0                   0.026072         0.000000
# LP001050       5282.0                   0.021204         0.666667
# LP001199       6216.0                   0.023166         0.666667
# LP001011       9613.0                   0.027775         0.666667
# LP001164       4230.0                   0.026478         0.000000
# LP002341       2600.0                   0.061538         0.500000
# LP002262       9504.0                   0.028935         0.750000
# LP001964       4734.0                   0.019645         0.000000
# LP001367       4082.0                   0.024498         0.500000
# LP002234       7167.0                   0.017860         0.000000
# LP001052       6642.0                   0.022734         0.500000
# LP002757       3680.0                   0.027717         0.000000
# LP002500       4611.0                   0.015181         0.750000
# LP002778       6633.0                   0.022067         0.666667
# LP001824       4725.0                   0.026032         0.500000
# LP002543       8333.0                   0.029521         0.666667

# %%
new_col_std = StandardScaler()
new_col_std.fit(new_columns_df)
pickle.dump(new_col_std, open('models_and_encoders/new_col_scaler.pkl', 'wb'))
new_columns_scaled = new_col_std.transform(new_columns_df)

# %%
new_columns_scaled_df = pd.DataFrame(data = new_columns_scaled, index = new_columns_df.index, columns = new_columns_df.columns)

# %%
new_columns_scaled_df.head()
# Out:
#           TotalIncome  LoanAmtToTotalIncomeRatio  DependentsRatio
# Loan_ID
# LP001002    -0.182240                   0.114833        -0.825068
# LP001003    -0.144818                  -0.334007         0.784671
# LP001005    -0.622808                  -0.223715        -0.825068
# LP001006    -0.322653                   0.032217        -0.825068
# LP001008    -0.158890                  -0.055823        -0.825068

# %%
new_columns_scaled_df.isna().sum()
# Out:
# TotalIncome                  0
# LoanAmtToTotalIncomeRatio    0
# DependentsRatio              0
# dtype: int64

# %%
all(full_df.index == new_columns_scaled_df.index)
# Out:
# True

# %%
full_df.head()
# Out:
#           ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002         0.073496          -0.555746 -3.376631e-16          0.275516
# LP001003        -0.133510          -0.040955 -2.182381e-01          0.275516
# LP001005        -0.392350          -0.555746 -9.548270e-01          0.275516
# LP001006        -0.460534           0.249212 -3.132818e-01          0.275516
# LP001008         0.098187          -0.555746 -6.379206e-02          0.275516
#
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001002       1        0              0             1             0
# LP001003       1        1              0             0             1
# LP001005       1        1              1             1             0
# LP001006       1        1              0             1             0
# LP001008       1        0              0             1             0
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001002             0              0                   1
# LP001003             0              0                   1
# LP001005             0              0                   1
# LP001006             0              0                   0
# LP001008             0              0                   1
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001002                       0                    0
# LP001003                       0                    1
# LP001005                       0                    0
# LP001006                       1                    0
# LP001008                       0                    0
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History  \
# Loan_ID
# LP001002                        0                    1               1
# LP001003                        0                    0               1
# LP001005                        0                    1               1
# LP001006                        0                    1               1
# LP001008                        0                    1               1
#
#           Loan_Status
# Loan_ID
# LP001002            1
# LP001003            0
# LP001005            1
# LP001006            1
# LP001008            1

# %%
full_df_engineered = pd.concat([new_columns_scaled_df, full_df], axis = 1)
full_df_engineered.sample(10)
# Out:
#           TotalIncome  LoanAmtToTotalIncomeRatio  DependentsRatio  \
# Loan_ID
# LP001671    -0.123013                  -0.656626        -0.825068
# LP001758     0.141884                   0.272317         1.321250
# LP001994    -0.427498                   0.044460        -0.825068
# LP002544    -0.407241                   0.650818         0.784671
# LP002807    -0.481004                   0.399959         1.321250
# LP002055    -0.135539                  -0.284164        -0.825068
# LP001318     0.754101                  -0.918448         1.321250
# LP001636    -0.375385                  -0.909880        -0.825068
# LP002175     0.008585                  -0.631825        -0.825068
# LP002684    -0.560952                   0.441267        -0.825068
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001671        -0.324329           0.405561   -0.396445          0.275516
# LP001758         0.139065           0.022882    0.755960          0.275516
# LP001994        -0.490457           0.080232   -0.503369          0.275516
# LP002544        -0.562729           0.275839   -0.182597          0.275516
# LP002807        -0.281979          -0.473133   -0.455847          0.275516
# LP002055        -0.365207           0.463253   -0.170716          0.275516
# LP001318         0.139065           1.374377    0.494590         -2.530152
# LP001636        -0.130730          -0.555746   -0.871664         -2.530152
# LP002175        -0.106203           0.240677   -0.194477          0.275516
# LP002684        -0.326945          -0.555746   -0.610293          0.275516
#
#           Gender  Married  Self_Employed  Dependents_0  Dependents_1  \
# Loan_ID
# LP001671       0        1              0             1             0
# LP001758       1        1              0             0             0
# LP001994       0        0              0             1             0
# LP002544       1        1              0             0             1
# LP002807       1        1              0             0             0
# LP002055       0        0              0             1             0
# LP001318       1        1              0             0             0
# LP001636       1        1              0             1             0
# LP002175       1        1              0             1             0
# LP002684       0        0              0             1             0
#
#           Dependents_2  Dependents_3+  Education_Graduate  \
# Loan_ID
# LP001671             0              0                   1
# LP001758             1              0                   1
# LP001994             0              0                   1
# LP002544             0              0                   0
# LP002807             1              0                   0
# LP002055             0              0                   1
# LP001318             1              0                   1
# LP001636             0              0                   1
# LP002175             0              0                   1
# LP002684             0              0                   0
#
#           Education_Not Graduate  Property_Area_Rural  \
# Loan_ID
# LP001671                       0                    0
# LP001758                       0                    0
# LP001994                       0                    0
# LP002544                       1                    1
# LP002807                       1                    0
# LP002055                       0                    1
# LP001318                       0                    0
# LP001636                       0                    0
# LP002175                       0                    0
# LP002684                       1                    1
#
#           Property_Area_Semiurban  Property_Area_Urban  Credit_History  \
# Loan_ID
# LP001671                        1                    0               1
# LP001758                        1                    0               1
# LP001994                        0                    1               0
# LP002544                        0                    0               1
# LP002807                        1                    0               1
# LP002055                        0                    0               0
# LP001318                        1                    0               1
# LP001636                        1                    0               1
# LP002175                        0                    1               1
# LP002684                        0                    0               1
#
#           Loan_Status
# Loan_ID
# LP001671            1
# LP001758            1
# LP001994            0
# LP002544            1
# LP002807            1
# LP002055            1
# LP001318            1
# LP001636            1
# LP002175            1
# LP002684            0

# %%
sns.heatmap(full_df_engineered.corr())
# Out:
# <Axes: >

# %%
full_df_engineered.to_excel('data/dataset_v3.xlsx')
